# %%
import pandas as pd
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_extraction.text import TfidfVectorizer
from lightgbm import LGBMClassifier
from sklearn.metrics import classification_report
from tqdm import tqdm
from transformers import AutoTokenizer, Trainer, TrainingArguments, AutoModelForSequenceClassification, DataCollatorWithPadding
from datasets import Dataset
from sklearn.preprocessing import OneHotEncoder

# %%
df = pd.read_csv("../data/raw/teknofest_train_final.csv",
                 sep="|")
df["pred"] = "nan"
df["text"] = df["text"].str.lower()
df.head()
# Out:
#                                      id  \
# 0  81c11060-a240-4d54-841b-9e2916039e85
# 1  be80ebbf-b322-4c3b-afa1-94932ea80731
# 2  f99e2513-83ed-4076-ac72-b9e2cff3f049
# 3  83ed2b2e-b815-4f36-9fc4-80a9050cf2d0
# 4  d93e05f7-bfdd-4cdb-99d8-3048761b30ff
#
#                                                 text  is_offensive     target  \
# 0                                        çürük dişli             1     INSULT
# 1  bu adamın islama ve müslümanlara verdiği zarar...             1     RACIST
# 2                               erkekler zora gelmez             1     SEXIST
# 3  utanmazın götüne kazık sokmuşlar bu tıkırtı ne...             1  PROFANITY
# 4     otomasyon< sistemlerine= doğrudan bağlanabilir             0      OTHER
#
#   pred
# 0  nan
# 1  nan
# 2  nan
# 3  nan
# 4  nan

# %%
enc = OneHotEncoder(sparse=False)

# %%
df["target_encoded"] = enc.fit_transform(df["target"].values.reshape(-1,1)).tolist()
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
skf = StratifiedKFold(n_splits=5,
                      shuffle=True,
                      random_state=1337)

splits = list(skf.split(df, df["target"]))

# %%
from transformers import AutoTokenizer

model_name = "dbmdz/bert-base-turkish-128k-uncased"
tokenizer = AutoTokenizer.from_pretrained(model_name)

# %%
import numpy as np
import torch


class TeknofestDataset(torch.utils.data.Dataset):
    def __init__(self, df, num_classes=5):
        self.df = df
        self.num_classes = num_classes
    
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        text, label = row.text, row.target_encoded
        encoding = tokenizer(text, max_length=128, padding="max_length", truncation=True)
        encoding = {key: torch.tensor(val) for key, val in encoding.items()}
        encoding["label"] = np.array(label).astype(np.float32).tolist()
        return dict(encoding)

# %%
from transformers import AutoModelForSequenceClassification
from datasets import load_metric
from transformers import TrainingArguments, Trainer
from torch import nn

def multiclass_logit2label(logits):
    sig = nn.Sigmoid()
    probs = sig(torch.FloatTensor(logits))

    max_idx = torch.argmax(probs, 1, keepdim=True)
    one_hot = torch.zeros(logits.shape)
    one_hot.scatter_(1, max_idx, 1)
    return one_hot.numpy()

# %%
batch_size = 64

for split_id, (train_idx, val_idx) in tqdm(enumerate(splits)):
    train_dataset = TeknofestDataset(df.iloc[train_idx].reset_index(drop=True))
    val_dataset = TeknofestDataset(df.iloc[val_idx].reset_index(drop=True))
    
    model = AutoModelForSequenceClassification.from_pretrained(model_name,
                                                           num_labels=5,
                                                              ignore_mismatched_sizes=True)
    
    training_args = TrainingArguments(
    f"teknofest23_{model_name.split('/')[-1]}_fold{split_id}",
    evaluation_strategy = "epoch",
    save_strategy = "epoch",
#     learning_rate=3e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=64,
    num_train_epochs=5,
#     weight_decay=0.01,
    load_best_model_at_end=False,
#     metric_for_best_model="f1",
    )

    trainer = Trainer(                  
        model=model,
        args=training_args,
        train_dataset=train_dataset,
        eval_dataset=val_dataset,
        tokenizer=tokenizer
    )

    trainer.train()
    
    preds = trainer.predict(val_dataset)
    
    preds = enc.inverse_transform(
        multiclass_logit2label(preds.predictions)
    ).flatten()
    
    df.loc[val_idx, "pred"] = preds
# Out:
# 0it [00:00, ?it/s]loading configuration file config.json from cache at /container_cache/huggingface/hub/models--dbmdz--bert-base-turkish-128k-uncased/snapshots/f5287aecee60f0c597c11c34341cb92d31c0e71b/config.json
# Model config BertConfig {
#   "_name_or_path": "dbmdz/bert-base-turkish-128k-uncased",
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2",
#     "3": "LABEL_3",
#     "4": "LABEL_4"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2,
#     "LABEL_3": 3,
#     "LABEL_4": 4
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.26.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 128000
# }
#
# loading weights file pytorch_model.bin from cache at /container_cache/huggingface/hub/models--dbmdz--bert-base-turkish-128k-uncased/snapshots/f5287aecee60f0c597c11c34341cb92d31c0e71b/pytorch_model.bin
# Some weights of the model checkpoint at dbmdz/bert-base-turkish-128k-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.decoder.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).
# /usr/local/lib/python3.8/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 10093
#   Num Epochs = 5
#   Instantaneous batch size per device = 64
#   Total train batch size (w. parallel, distributed & accumulation) = 64
#   Gradient Accumulation steps = 1
#   Total optimization steps = 790
#   Number of trainable parameters = 184349189
#     <div>
#
#       <progress value='790' max='790' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [790/790 02:42, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.098842</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.095592</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.097167</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.109100</td>
#       <td>0.091989</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.109100</td>
#       <td>0.090763</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 2524
#   Batch size = 64
# Saving model checkpoint to teknofest23_bert-base-turkish-128k-uncased_fold0/checkpoint-158
# Configuration saved in teknofest23_bert-base-turkish-128k-uncased_fold0/checkpoint-158/config.json
# Model weights saved in teknofest23_bert-base-turkish-128k-uncased_fold0/checkpoint-158/pytorch_model.bin
# tokenizer config file saved in teknofest23_bert-base-turkish-128k-uncased_fold0/checkpoint-158/tokenizer_config.json
# Special tokens file saved in teknofest23_bert-base-turkish-128k-uncased_fold0/checkpoint-158/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 2524
#   Batch size = 64
# Saving model checkpoint to teknofest23_bert-base-turkish-128k-uncased_fold0/checkpoint-316
# Configuration saved in teknofest23_bert-base-turkish-128k-uncased_fold0/checkpoint-316/config.json
# Model weights saved in teknofest23_bert-base-turkish-128k-uncased_fold0/checkpoint-316/pytorch_model.bin
# tokenizer config file saved in teknofest23_bert-base-turkish-128k-uncased_fold0/checkpoint-316/tokenizer_config.json
# Special tokens file saved in teknofest23_bert-base-turkish-128k-uncased_fold0/checkpoint-316/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 2524
#   Batch size = 64
# Saving model checkpoint to teknofest23_bert-base-turkish-128k-uncased_fold0/checkpoint-474
# Configuration saved in teknofest23_bert-base-turkish-128k-uncased_fold0/checkpoint-474/config.json
# Model weights saved in teknofest23_bert-base-turkish-128k-uncased_fold0/checkpoint-474/pytorch_model.bin
# tokenizer config file saved in teknofest23_bert-base-turkish-128k-uncased_fold0/checkpoint-474/tokenizer_config.json
# Special tokens file saved in teknofest23_bert-base-turkish-128k-uncased_fold0/checkpoint-474/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 2524
#   Batch size = 64
# Saving model checkpoint to teknofest23_bert-base-turkish-128k-uncased_fold0/checkpoint-632
# Configuration saved in teknofest23_bert-base-turkish-128k-uncased_fold0/checkpoint-632/config.json
# Model weights saved in teknofest23_bert-base-turkish-128k-uncased_fold0/checkpoint-632/pytorch_model.bin
# tokenizer config file saved in teknofest23_bert-base-turkish-128k-uncased_fold0/checkpoint-632/tokenizer_config.json
# Special tokens file saved in teknofest23_bert-base-turkish-128k-uncased_fold0/checkpoint-632/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 2524
#   Batch size = 64
# Saving model checkpoint to teknofest23_bert-base-turkish-128k-uncased_fold0/checkpoint-790
# Configuration saved in teknofest23_bert-base-turkish-128k-uncased_fold0/checkpoint-790/config.json
# Model weights saved in teknofest23_bert-base-turkish-128k-uncased_fold0/checkpoint-790/pytorch_model.bin
# tokenizer config file saved in teknofest23_bert-base-turkish-128k-uncased_fold0/checkpoint-790/tokenizer_config.json
# Special tokens file saved in teknofest23_bert-base-turkish-128k-uncased_fold0/checkpoint-790/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# ***** Running Prediction *****
#   Num examples = 2524
#   Batch size = 64
# 1it [02:46, 166.92s/it]loading configuration file config.json from cache at /container_cache/huggingface/hub/models--dbmdz--bert-base-turkish-128k-uncased/snapshots/f5287aecee60f0c597c11c34341cb92d31c0e71b/config.json
# Model config BertConfig {
#   "_name_or_path": "dbmdz/bert-base-turkish-128k-uncased",
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2",
#     "3": "LABEL_3",
#     "4": "LABEL_4"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2,
#     "LABEL_3": 3,
#     "LABEL_4": 4
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.26.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 128000
# }
#
# loading weights file pytorch_model.bin from cache at /container_cache/huggingface/hub/models--dbmdz--bert-base-turkish-128k-uncased/snapshots/f5287aecee60f0c597c11c34341cb92d31c0e71b/pytorch_model.bin
# Some weights of the model checkpoint at dbmdz/bert-base-turkish-128k-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.decoder.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).
# /usr/local/lib/python3.8/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 10093
#   Num Epochs = 5
#   Instantaneous batch size per device = 64
#   Total train batch size (w. parallel, distributed & accumulation) = 64
#   Gradient Accumulation steps = 1
#   Total optimization steps = 790
#   Number of trainable parameters = 184349189
#     <div>
#
#       <progress value='790' max='790' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [790/790 02:42, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.099233</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.075663</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.079283</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.097800</td>
#       <td>0.078478</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.097800</td>
#       <td>0.076619</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 2524
#   Batch size = 64
# Saving model checkpoint to teknofest23_bert-base-turkish-128k-uncased_fold1/checkpoint-158
# Configuration saved in teknofest23_bert-base-turkish-128k-uncased_fold1/checkpoint-158/config.json
# Model weights saved in teknofest23_bert-base-turkish-128k-uncased_fold1/checkpoint-158/pytorch_model.bin
# tokenizer config file saved in teknofest23_bert-base-turkish-128k-uncased_fold1/checkpoint-158/tokenizer_config.json
# Special tokens file saved in teknofest23_bert-base-turkish-128k-uncased_fold1/checkpoint-158/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 2524
#   Batch size = 64
# Saving model checkpoint to teknofest23_bert-base-turkish-128k-uncased_fold1/checkpoint-316
# Configuration saved in teknofest23_bert-base-turkish-128k-uncased_fold1/checkpoint-316/config.json
# Model weights saved in teknofest23_bert-base-turkish-128k-uncased_fold1/checkpoint-316/pytorch_model.bin
# tokenizer config file saved in teknofest23_bert-base-turkish-128k-uncased_fold1/checkpoint-316/tokenizer_config.json
# Special tokens file saved in teknofest23_bert-base-turkish-128k-uncased_fold1/checkpoint-316/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 2524
#   Batch size = 64
# Saving model checkpoint to teknofest23_bert-base-turkish-128k-uncased_fold1/checkpoint-474
# Configuration saved in teknofest23_bert-base-turkish-128k-uncased_fold1/checkpoint-474/config.json
# Model weights saved in teknofest23_bert-base-turkish-128k-uncased_fold1/checkpoint-474/pytorch_model.bin
# tokenizer config file saved in teknofest23_bert-base-turkish-128k-uncased_fold1/checkpoint-474/tokenizer_config.json
# Special tokens file saved in teknofest23_bert-base-turkish-128k-uncased_fold1/checkpoint-474/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 2524
#   Batch size = 64
# Saving model checkpoint to teknofest23_bert-base-turkish-128k-uncased_fold1/checkpoint-632
# Configuration saved in teknofest23_bert-base-turkish-128k-uncased_fold1/checkpoint-632/config.json
# Model weights saved in teknofest23_bert-base-turkish-128k-uncased_fold1/checkpoint-632/pytorch_model.bin
# tokenizer config file saved in teknofest23_bert-base-turkish-128k-uncased_fold1/checkpoint-632/tokenizer_config.json
# Special tokens file saved in teknofest23_bert-base-turkish-128k-uncased_fold1/checkpoint-632/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 2524
#   Batch size = 64
# Saving model checkpoint to teknofest23_bert-base-turkish-128k-uncased_fold1/checkpoint-790
# Configuration saved in teknofest23_bert-base-turkish-128k-uncased_fold1/checkpoint-790/config.json
# Model weights saved in teknofest23_bert-base-turkish-128k-uncased_fold1/checkpoint-790/pytorch_model.bin
# tokenizer config file saved in teknofest23_bert-base-turkish-128k-uncased_fold1/checkpoint-790/tokenizer_config.json
# Special tokens file saved in teknofest23_bert-base-turkish-128k-uncased_fold1/checkpoint-790/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# ***** Running Prediction *****
#   Num examples = 2524
#   Batch size = 64
# 2it [05:33, 166.43s/it]loading configuration file config.json from cache at /container_cache/huggingface/hub/models--dbmdz--bert-base-turkish-128k-uncased/snapshots/f5287aecee60f0c597c11c34341cb92d31c0e71b/config.json
# Model config BertConfig {
#   "_name_or_path": "dbmdz/bert-base-turkish-128k-uncased",
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2",
#     "3": "LABEL_3",
#     "4": "LABEL_4"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2,
#     "LABEL_3": 3,
#     "LABEL_4": 4
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.26.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 128000
# }
#
# loading weights file pytorch_model.bin from cache at /container_cache/huggingface/hub/models--dbmdz--bert-base-turkish-128k-uncased/snapshots/f5287aecee60f0c597c11c34341cb92d31c0e71b/pytorch_model.bin
# Some weights of the model checkpoint at dbmdz/bert-base-turkish-128k-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.decoder.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).
# /usr/local/lib/python3.8/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 10094
#   Num Epochs = 5
#   Instantaneous batch size per device = 64
#   Total train batch size (w. parallel, distributed & accumulation) = 64
#   Gradient Accumulation steps = 1
#   Total optimization steps = 790
#   Number of trainable parameters = 184349189
#     <div>
#
#       <progress value='790' max='790' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [790/790 02:36, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.094977</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.083210</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.081473</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.105100</td>
#       <td>0.090126</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.105100</td>
#       <td>0.087209</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 2523
#   Batch size = 64
# Saving model checkpoint to teknofest23_bert-base-turkish-128k-uncased_fold2/checkpoint-158
# Configuration saved in teknofest23_bert-base-turkish-128k-uncased_fold2/checkpoint-158/config.json
# Model weights saved in teknofest23_bert-base-turkish-128k-uncased_fold2/checkpoint-158/pytorch_model.bin
# tokenizer config file saved in teknofest23_bert-base-turkish-128k-uncased_fold2/checkpoint-158/tokenizer_config.json
# Special tokens file saved in teknofest23_bert-base-turkish-128k-uncased_fold2/checkpoint-158/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 2523
#   Batch size = 64
# Saving model checkpoint to teknofest23_bert-base-turkish-128k-uncased_fold2/checkpoint-316
# Configuration saved in teknofest23_bert-base-turkish-128k-uncased_fold2/checkpoint-316/config.json
# Model weights saved in teknofest23_bert-base-turkish-128k-uncased_fold2/checkpoint-316/pytorch_model.bin
# tokenizer config file saved in teknofest23_bert-base-turkish-128k-uncased_fold2/checkpoint-316/tokenizer_config.json
# Special tokens file saved in teknofest23_bert-base-turkish-128k-uncased_fold2/checkpoint-316/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 2523
#   Batch size = 64
# Saving model checkpoint to teknofest23_bert-base-turkish-128k-uncased_fold2/checkpoint-474
# Configuration saved in teknofest23_bert-base-turkish-128k-uncased_fold2/checkpoint-474/config.json
# Model weights saved in teknofest23_bert-base-turkish-128k-uncased_fold2/checkpoint-474/pytorch_model.bin
# tokenizer config file saved in teknofest23_bert-base-turkish-128k-uncased_fold2/checkpoint-474/tokenizer_config.json
# Special tokens file saved in teknofest23_bert-base-turkish-128k-uncased_fold2/checkpoint-474/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 2523
#   Batch size = 64
# Saving model checkpoint to teknofest23_bert-base-turkish-128k-uncased_fold2/checkpoint-632
# Configuration saved in teknofest23_bert-base-turkish-128k-uncased_fold2/checkpoint-632/config.json
# Model weights saved in teknofest23_bert-base-turkish-128k-uncased_fold2/checkpoint-632/pytorch_model.bin
# tokenizer config file saved in teknofest23_bert-base-turkish-128k-uncased_fold2/checkpoint-632/tokenizer_config.json
# Special tokens file saved in teknofest23_bert-base-turkish-128k-uncased_fold2/checkpoint-632/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 2523
#   Batch size = 64
# Saving model checkpoint to teknofest23_bert-base-turkish-128k-uncased_fold2/checkpoint-790
# Configuration saved in teknofest23_bert-base-turkish-128k-uncased_fold2/checkpoint-790/config.json
# Model weights saved in teknofest23_bert-base-turkish-128k-uncased_fold2/checkpoint-790/pytorch_model.bin
# tokenizer config file saved in teknofest23_bert-base-turkish-128k-uncased_fold2/checkpoint-790/tokenizer_config.json
# Special tokens file saved in teknofest23_bert-base-turkish-128k-uncased_fold2/checkpoint-790/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# ***** Running Prediction *****
#   Num examples = 2523
#   Batch size = 64
# 3it [08:13, 163.75s/it]loading configuration file config.json from cache at /container_cache/huggingface/hub/models--dbmdz--bert-base-turkish-128k-uncased/snapshots/f5287aecee60f0c597c11c34341cb92d31c0e71b/config.json
# Model config BertConfig {
#   "_name_or_path": "dbmdz/bert-base-turkish-128k-uncased",
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2",
#     "3": "LABEL_3",
#     "4": "LABEL_4"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2,
#     "LABEL_3": 3,
#     "LABEL_4": 4
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.26.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 128000
# }
#
# loading weights file pytorch_model.bin from cache at /container_cache/huggingface/hub/models--dbmdz--bert-base-turkish-128k-uncased/snapshots/f5287aecee60f0c597c11c34341cb92d31c0e71b/pytorch_model.bin
# Some weights of the model checkpoint at dbmdz/bert-base-turkish-128k-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.decoder.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).
# /usr/local/lib/python3.8/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 10094
#   Num Epochs = 5
#   Instantaneous batch size per device = 64
#   Total train batch size (w. parallel, distributed & accumulation) = 64
#   Gradient Accumulation steps = 1
#   Total optimization steps = 790
#   Number of trainable parameters = 184349189
#     <div>
#
#       <progress value='790' max='790' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [790/790 02:36, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.088655</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.085967</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.083617</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.091100</td>
#       <td>0.076185</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.091100</td>
#       <td>0.079169</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 2523
#   Batch size = 64
# Saving model checkpoint to teknofest23_bert-base-turkish-128k-uncased_fold3/checkpoint-158
# Configuration saved in teknofest23_bert-base-turkish-128k-uncased_fold3/checkpoint-158/config.json
# Model weights saved in teknofest23_bert-base-turkish-128k-uncased_fold3/checkpoint-158/pytorch_model.bin
# tokenizer config file saved in teknofest23_bert-base-turkish-128k-uncased_fold3/checkpoint-158/tokenizer_config.json
# Special tokens file saved in teknofest23_bert-base-turkish-128k-uncased_fold3/checkpoint-158/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 2523
#   Batch size = 64
# Saving model checkpoint to teknofest23_bert-base-turkish-128k-uncased_fold3/checkpoint-316
# Configuration saved in teknofest23_bert-base-turkish-128k-uncased_fold3/checkpoint-316/config.json
# Model weights saved in teknofest23_bert-base-turkish-128k-uncased_fold3/checkpoint-316/pytorch_model.bin
# tokenizer config file saved in teknofest23_bert-base-turkish-128k-uncased_fold3/checkpoint-316/tokenizer_config.json
# Special tokens file saved in teknofest23_bert-base-turkish-128k-uncased_fold3/checkpoint-316/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 2523
#   Batch size = 64
# Saving model checkpoint to teknofest23_bert-base-turkish-128k-uncased_fold3/checkpoint-474
# Configuration saved in teknofest23_bert-base-turkish-128k-uncased_fold3/checkpoint-474/config.json
# Model weights saved in teknofest23_bert-base-turkish-128k-uncased_fold3/checkpoint-474/pytorch_model.bin
# tokenizer config file saved in teknofest23_bert-base-turkish-128k-uncased_fold3/checkpoint-474/tokenizer_config.json
# Special tokens file saved in teknofest23_bert-base-turkish-128k-uncased_fold3/checkpoint-474/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 2523
#   Batch size = 64
# Saving model checkpoint to teknofest23_bert-base-turkish-128k-uncased_fold3/checkpoint-632
# Configuration saved in teknofest23_bert-base-turkish-128k-uncased_fold3/checkpoint-632/config.json
# Model weights saved in teknofest23_bert-base-turkish-128k-uncased_fold3/checkpoint-632/pytorch_model.bin
# tokenizer config file saved in teknofest23_bert-base-turkish-128k-uncased_fold3/checkpoint-632/tokenizer_config.json
# Special tokens file saved in teknofest23_bert-base-turkish-128k-uncased_fold3/checkpoint-632/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 2523
#   Batch size = 64
# Saving model checkpoint to teknofest23_bert-base-turkish-128k-uncased_fold3/checkpoint-790
# Configuration saved in teknofest23_bert-base-turkish-128k-uncased_fold3/checkpoint-790/config.json
# Model weights saved in teknofest23_bert-base-turkish-128k-uncased_fold3/checkpoint-790/pytorch_model.bin
# tokenizer config file saved in teknofest23_bert-base-turkish-128k-uncased_fold3/checkpoint-790/tokenizer_config.json
# Special tokens file saved in teknofest23_bert-base-turkish-128k-uncased_fold3/checkpoint-790/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# ***** Running Prediction *****
#   Num examples = 2523
#   Batch size = 64
# 4it [10:54, 162.55s/it]loading configuration file config.json from cache at /container_cache/huggingface/hub/models--dbmdz--bert-base-turkish-128k-uncased/snapshots/f5287aecee60f0c597c11c34341cb92d31c0e71b/config.json
# Model config BertConfig {
#   "_name_or_path": "dbmdz/bert-base-turkish-128k-uncased",
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2",
#     "3": "LABEL_3",
#     "4": "LABEL_4"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2,
#     "LABEL_3": 3,
#     "LABEL_4": 4
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.26.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 128000
# }
#
# loading weights file pytorch_model.bin from cache at /container_cache/huggingface/hub/models--dbmdz--bert-base-turkish-128k-uncased/snapshots/f5287aecee60f0c597c11c34341cb92d31c0e71b/pytorch_model.bin
# Some weights of the model checkpoint at dbmdz/bert-base-turkish-128k-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.decoder.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-turkish-128k-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).
# /usr/local/lib/python3.8/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 10094
#   Num Epochs = 5
#   Instantaneous batch size per device = 64
#   Total train batch size (w. parallel, distributed & accumulation) = 64
#   Gradient Accumulation steps = 1
#   Total optimization steps = 790
#   Number of trainable parameters = 184349189
#     <div>
#
#       <progress value='790' max='790' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [790/790 02:34, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.089254</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.081264</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.080185</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.102400</td>
#       <td>0.077118</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.102400</td>
#       <td>0.077072</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 2523
#   Batch size = 64
# Saving model checkpoint to teknofest23_bert-base-turkish-128k-uncased_fold4/checkpoint-158
# Configuration saved in teknofest23_bert-base-turkish-128k-uncased_fold4/checkpoint-158/config.json
# Model weights saved in teknofest23_bert-base-turkish-128k-uncased_fold4/checkpoint-158/pytorch_model.bin
# tokenizer config file saved in teknofest23_bert-base-turkish-128k-uncased_fold4/checkpoint-158/tokenizer_config.json
# Special tokens file saved in teknofest23_bert-base-turkish-128k-uncased_fold4/checkpoint-158/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 2523
#   Batch size = 64
# Saving model checkpoint to teknofest23_bert-base-turkish-128k-uncased_fold4/checkpoint-316
# Configuration saved in teknofest23_bert-base-turkish-128k-uncased_fold4/checkpoint-316/config.json
# Model weights saved in teknofest23_bert-base-turkish-128k-uncased_fold4/checkpoint-316/pytorch_model.bin
# tokenizer config file saved in teknofest23_bert-base-turkish-128k-uncased_fold4/checkpoint-316/tokenizer_config.json
# Special tokens file saved in teknofest23_bert-base-turkish-128k-uncased_fold4/checkpoint-316/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 2523
#   Batch size = 64
# Saving model checkpoint to teknofest23_bert-base-turkish-128k-uncased_fold4/checkpoint-474
# Configuration saved in teknofest23_bert-base-turkish-128k-uncased_fold4/checkpoint-474/config.json
# Model weights saved in teknofest23_bert-base-turkish-128k-uncased_fold4/checkpoint-474/pytorch_model.bin
# tokenizer config file saved in teknofest23_bert-base-turkish-128k-uncased_fold4/checkpoint-474/tokenizer_config.json
# Special tokens file saved in teknofest23_bert-base-turkish-128k-uncased_fold4/checkpoint-474/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 2523
#   Batch size = 64
# Saving model checkpoint to teknofest23_bert-base-turkish-128k-uncased_fold4/checkpoint-632
# Configuration saved in teknofest23_bert-base-turkish-128k-uncased_fold4/checkpoint-632/config.json
# Model weights saved in teknofest23_bert-base-turkish-128k-uncased_fold4/checkpoint-632/pytorch_model.bin
# tokenizer config file saved in teknofest23_bert-base-turkish-128k-uncased_fold4/checkpoint-632/tokenizer_config.json
# Special tokens file saved in teknofest23_bert-base-turkish-128k-uncased_fold4/checkpoint-632/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 2523
#   Batch size = 64
# Saving model checkpoint to teknofest23_bert-base-turkish-128k-uncased_fold4/checkpoint-790
# Configuration saved in teknofest23_bert-base-turkish-128k-uncased_fold4/checkpoint-790/config.json
# Model weights saved in teknofest23_bert-base-turkish-128k-uncased_fold4/checkpoint-790/pytorch_model.bin
# tokenizer config file saved in teknofest23_bert-base-turkish-128k-uncased_fold4/checkpoint-790/tokenizer_config.json
# Special tokens file saved in teknofest23_bert-base-turkish-128k-uncased_fold4/checkpoint-790/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# ***** Running Prediction *****
#   Num examples = 2523
#   Batch size = 64
# 5it [13:32, 162.50s/it]

# %%
print(classification_report(df["target"], df["pred"], digits=4))
# Out:
#               precision    recall  f1-score   support
#
#       INSULT     0.9051    0.8991    0.9021      2419
#        OTHER     0.9538    0.9422    0.9480      3616
#    PROFANITY     0.9582    0.9462    0.9522      2398
#       RACIST     0.9335    0.9551    0.9442      2072
#       SEXIST     0.9387    0.9574    0.9480      2112
#
#     accuracy                         0.9394     12617
#    macro avg     0.9379    0.9400    0.9389     12617
# weighted avg     0.9394    0.9394    0.9394     12617
